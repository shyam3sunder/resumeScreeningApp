# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/drive/MyDrive/UpdatedResumeDataSet.csv')

# %%
data.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
data.shape
# Out:
# (962, 2)

# %%
data['Category'].value_counts()
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Sales                        40
# Data Science                 40
# Mechanical Engineer          40
# ETL Developer                40
# Blockchain                   40
# Operations Manager           40
# Arts                         36
# Database                     33
# Health and fitness           30
# PMO                          30
# Electrical Engineering       30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# Civil Engineer               24
# SAP Developer                24
# Advocate                     20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['Category'])
plt.xticks(rotation=90)
plt.show()

# %%
data['Category'].unique()
# Out:
# array(['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing',
#        'Mechanical Engineer', 'Sales', 'Health and fitness',
#        'Civil Engineer', 'Java Developer', 'Business Analyst',
#        'SAP Developer', 'Automation Testing', 'Electrical Engineering',
#        'Operations Manager', 'Python Developer', 'DevOps Engineer',
#        'Network Security Engineer', 'PMO', 'Database', 'Hadoop',
#        'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing'],
#       dtype=object)

# %%
plt.figure(figsize=(10,10))
counts = data['Category'].value_counts()
labels = data['Category'].unique()
plt.pie(counts,labels=labels,autopct='%1.2f%%')
plt.show()

# %%
data['Category'][0]
# Out:
# 'Data Science'

# %%
data['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %%
import re
def ResumeClean(txt):
  cleanText=re.sub('http\S+\s',' ',txt)
  cleanText = re.sub('RT|cc', ' ', cleanText)
  cleanText = re.sub('#\S+\s', ' ', cleanText)
  cleanText = re.sub('@\S+\s', ' ', cleanText)
  cleanText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', cleanText)
  cleanText = re.sub(r'[^\x00-\x7f]', ' ', cleanText)
  cleanText = re.sub('\s+', ' ', cleanText)
  return cleanText

# %%
data['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %%
data['Resume'] = data['Resume'].apply(lambda x: ResumeClean(x))

# %%
data['Resume'][0]
# Out:
# 'Skills Programming Languages Python pandas numpy scipy scikit learn matplotlib Sql Java JavaScript JQuery Machine learning Regression SVM Na ve Bayes KNN Random Forest Decision Trees Boosting techniques Cluster Analysis Word Embedding Sentiment Analysis Natural Language processing Dimensionality reduction Topic Modelling LDA NMF PCA Neural Nets Database Visualizations Mysql SqlServer Cassandra Hbase ElasticSearch D3 js DC js Plotly kibana matplotlib ggplot Tableau Others Regular Expression HTML CSS Angular 6 Logstash Kafka Python Flask Git Docker computer vision Open CV and understanding of Deep learning Education Details Data Science Assurance Associate Data Science Assurance Associate Ernst Young LLP Skill Details JAVASCRIPT Exprience 24 months jQuery Exprience 24 months Python Exprience 24 monthsCompany Details company Ernst Young LLP description Fraud Investigations and Dispute Services Assurance TECHNOLOGY ASSISTED REVIEW TAR Technology Assisted Review assists in a elerating th
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(data['Category'])
data['Category'] = le.transform(data['Category'])

# %%
data.Category.unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
data.head()
# Out:
#    Category                                             Resume
# 0         6  Skills Programming Languages Python pandas num...
# 1         6  Education Details May 2013 to May 2017 B E UIT...
# 2         6  Areas of Interest Deep Learning Control System...
# 3         6  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4         6  Education Details MCA YMCAUST Faridabad Haryan...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')

tfidf.fit(data['Resume'])
requiredText  = tfidf.transform(data['Resume'])

# %%
data['Resume'][0]
# Out:
# 'Skills Programming Languages Python pandas numpy scipy scikit learn matplotlib Sql Java JavaScript JQuery Machine learning Regression SVM Na ve Bayes KNN Random Forest Decision Trees Boosting techniques Cluster Analysis Word Embedding Sentiment Analysis Natural Language processing Dimensionality reduction Topic Modelling LDA NMF PCA Neural Nets Database Visualizations Mysql SqlServer Cassandra Hbase ElasticSearch D3 js DC js Plotly kibana matplotlib ggplot Tableau Others Regular Expression HTML CSS Angular 6 Logstash Kafka Python Flask Git Docker computer vision Open CV and understanding of Deep learning Education Details Data Science Assurance Associate Data Science Assurance Associate Ernst Young LLP Skill Details JAVASCRIPT Exprience 24 months jQuery Exprience 24 months Python Exprience 24 monthsCompany Details company Ernst Young LLP description Fraud Investigations and Dispute Services Assurance TECHNOLOGY ASSISTED REVIEW TAR Technology Assisted Review assists in a elerating th
# ...

# %%
requiredText
# Out:
# <962x7351 sparse matrix of type '<class 'numpy.float64'>'
# 	with 164261 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(requiredText, data['Category'], test_size=0.2, random_state=42)

# %%
import numpy as np

# Convert the sparse matrix to a dense NumPy array
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# %%
# Check the shape of the dense matrices
print(X_train_dense.shape)  # Should be (num_samples, num_features)
print(X_test_dense.shape)   # Should be (num_samples, num_features)
# Out:
# (769, 7351)
# (193, 7351)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=7351, activation='relu'))  # Input dimension should match the number of features
model.add(Dropout(0.5))  # Dropout layer to prevent overfitting
model.add(Dense(64, activation='relu'))
model.add(Dense(len(data['Category'].unique()), activation='softmax'))  # Output layer for multi-class classification

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 128)                 │         941,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
history = model.fit(X_train_dense, y_train, epochs=15, batch_size=32, validation_data=(X_test_dense, y_test))
# Out:
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.1782 - loss: 3.1738 - val_accuracy: 0.4197 - val_loss: 2.9442
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4304 - loss: 2.8007 - val_accuracy: 0.6788 - val_loss: 2.2706
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6567 - loss: 2.0445 - val_accuracy: 0.8653 - val_loss: 1.4057
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8835 - loss: 1.2087 - val_accuracy: 0.9585 - val_loss: 0.7694
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9760 - loss: 0.6340 - val_accuracy: 0.9948 - val_loss: 0.3902
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9911 - loss: 0.3627 - val_accuracy: 0.9948 - val_loss: 0.2033
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.2003 - val_accuracy: 0.9948 - val_loss: 0.1134
# Epoch 8/15
# ...

# %%
loss, accuracy = model.evaluate(X_test_dense, y_test, verbose=1)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0162
# Test loss: 0.023527881130576134
# Test accuracy: 0.9948186278343201

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Predict on the test set
y_pred = model.predict(X_test_dense)
y_pred_classes = np.argmax(y_pred, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification report
report = classification_report(y_test, y_pred_classes)
print(report)
# Out:
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b978c56d6c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         6
# ...

# %%
import pickle
pickle.dump(tfidf,open('tfidf.pkl','wb'))
pickle.dump(model, open('model.pkl', 'wb'))

# %%
myresume = """DEEVPI MAYEE KAMILA
UNDERGRADUATE IN ELECTRONICS & INSTRUMENTATION
78949 60548

EDUCATION
ODISHA UNIVERSITY OF TECHNOLOGY
AND RESEARCH
2021-2023
Acquired an aggregate of 9.1 CGPA upto 4th semester.
DEEPIKA ENGLISH MEDIUM SCHOOL 2019-2020
Acquired an aggregate percentage of 91% in higher secondary board Examination(CBSE).
DEEPIKA ENGLISH MEDIUM SCHOOL 2017-2018
Acquired an aggregate percentage of 94.2% in the elementary board examination (CBSE).
ACHIVEMENTS
ODISHA UNIVERSITY OF
TECHNOLOGY AND RESEARCH 2021-2023
Scoring an aggregate of 9.1 CGPA and got THE SCHOLARSHIP OF MERIT BY
OUTR.
DEEPIKA ENGLISH MEDIUM SCHOOL 2016-2017
Outstanding achiever of the year for academics' awardee. Scored above 9 CGPA (2006-2018).
Position Of Responsibility
2021-2025
Placement Coordinator for the batch 2021-2025.Maintained database of student resumes and employer contacts. Assisted students in resume building, interview preparation, and professional development.
2021-2025
A distinguished member of SPECTRUM (The Technical club), which is well versed in hardware, software and design wing.
PROFILE
I am a hardworking and passionate person, thriving towards my interest in the field of ELECTRONICS AND INSTRUMENTATION, my strong points being my solid basics and an excellent academic career that speaks for itself. I am currently pursuing my bachelor's degree in ELECTRONICS AND INSTRUMENTATION department, which helps me gaining knowledge and refines my pre-requisite. which has in turn helped me in achieving a cumulative gpa of 9.1.
SKILLS
•MATLAB
•PROTEUS	• LABVIEW
•SIMULINK	• Problem Solving
•VIVADO	•Critical Thinking
•MULTISIM	•Leadership Skills
INTERNSHIP
STEEL AUTHORITY OF INDIA LIMITED , Rourkela
Electronics And Automation Intern (8th May 2023 To 7th June 2023)
*Worked as a trainee to learn about Electronics application and Automation in the process flow of a production unit under senior Electronics Engineers.
# %earned about how automation is used to optimize the work flow to reduce production time and ensure high quality of products.
PROJECTS
Amplitude Modulator And Demodulator
• Modulator is designed using IN4148 diode (for fast switching) and a tank circuit which produces 10KHZ frequency works as carrier frequency for signal transmission.
Decibal Meter (Audio Intensity Indicator) Using Lm3915
• Designed to detect magnitude level of input audio signal using visual display through sequential glowing of LEDs using LM3915 'C.
Simple Line Follower Robot
• Developed the model using 8051 Microcontroller. two IR sensors, motors and motor driver IC(L2998N).
Intruder Alert Alarm (Using Hall Sensor)
• Built using Hall sensor (MH183) and BC557 PNP transistor,
BC547 NPN transistor.

"""

# %%
print(type(tfidf))
print(type(model))
# Out:
# <class 'sklearn.feature_extraction.text.TfidfVectorizer'>
# <class 'keras.src.models.sequential.Sequential'>

# %%
import pickle
import numpy as np

# Load the trained TF-IDF vectorizer and model
with open('tfidf.pkl', 'rb') as file:
    tfidf = pickle.load(file)

with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# Define the function to clean the resume (if not already defined)
def ResumeClean(resume):
    # Implement your resume cleaning logic here
    return resume

cleaned_resume = ResumeClean(myresume)

# Transform the cleaned resume using the loaded TF-IDF vectorizer
input_features = tfidf.transform([cleaned_resume])

# Make the prediction using the loaded model
prediction = model.predict(input_features)

# Check the type and value of prediction
print("Prediction type:", type(prediction))
print("Prediction value:", prediction)

# Extract the predicted class index
# If the model's output is one-hot encoded, use np.argmax to get the index
prediction_id = np.argmax(prediction, axis=-1)[0]

# Define your category mapping
category_mapping = {
    15: "Java Developer",
    23: "Testing",
    8: "DevOps Engineer",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "ETL Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate",
}

# Map category ID to category name
category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print("Prediction ID:", prediction_id)
# Out:
# WARNING:tensorflow:6 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b980b360940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Prediction type: <class 'numpy.ndarray'>
# Prediction value: [[0.03462788 0.06814659 0.14469135 0.02249791 0.07561436 0.02159898
#   0.02246746 0.05514722 0.0166295  0.0488905  0.04551402 0.01007155
# ...
